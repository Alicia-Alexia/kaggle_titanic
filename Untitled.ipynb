# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize
import catboost 
from sklearn.model_selection import train_test_split
from sklearn import model_selection, tree, preprocessing, metrics, linear_model
from sklearn.svm import LinearSVC
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression, LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier, Pool, cv

# %%
# Abrindo arquivos 
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Conferindo quantos estão null
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# criação da variavel passengerId com os dados da coluna PassengerId do dataframe test
passengerId = test['PassengerId']
# criando dataframe titanic_df,titanic_df agora contém todas as linhas tanto de train quanto de test, com um índice contínuo 
# a partir de 0.
titanic_df = pd.concat([train, test], ignore_index=True)

# %%
titanic_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
#criando um dataframe vazio para preenche-lo com dados posteriomente
df = pd.DataFrame()

# %%
# wuantos valores unicos se tem
titanic_df['Survived'].nunique()
# Out:
# 2

# %%
# observando quais são os valores 
titanic_df['Survived'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
titanic_df['Survived'].isnull().sum()
# Out:
# 418

# %%
titanic_df['Survived'].value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
# criando um gráfico de contagem (countplot) da coluna 'Survived' no DataFrame titanic_df
sns.countplot(data = titanic_df, x = 'Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#função para saber valores unicos e valores nulos cria gráfico de contagem ou de distribuição a partir do valor de count
def titanic_func(data, column, count = True):
    print(f'Quantidade de valores únicos: {data[column].nunique()}')
    print(f'\nQuais são os valores únicos: {data[column].unique()}')
    print(f'\nQuantidade de valores nulos: {data[column].isnull().sum()}')
    print(f'\nQuantidade por opção: \n{data[column].value_counts()}')
    
    if count == True:
        sns.countplot(data = data, x = column, hue = 'Survived')
    else:
        sns.displot(data[column], kde =True)

titanic_func(titanic_df, 'Survived')
# Out:
# Quantidade de valores únicos: 2
#
# Quais são os valores únicos: [ 0.  1. nan]
#
# Quantidade de valores nulos: 418
#
# Quantidade por opção:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
# acrescentado a coluna Survived no dataframe df 
df['Survived'] = titanic_df['Survived']
df
# Out:
#       Survived
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          0.0
# ...        ...
# 1304       NaN
# 1305       NaN
# 1306       NaN
# 1307       NaN
# 1308       NaN
#
# [1309 rows x 1 columns]

# %% [markdown]
# ### Pclass

# %%
# Utilizando a função para saber algumas informações da coluna Pclass
titanic_func(titanic_df, 'Pclass')
# Out:
# Quantidade de valores únicos: 3
#
# Quais são os valores únicos: [3 1 2]
#
# Quantidade de valores nulos: 0
#
# Quantidade por opção:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
#acrescentando a coluna Pclass no dataframe df
df['Pclass'] = titanic_df['Pclass']
df
# Out:
#       Survived  Pclass
# 0          0.0       3
# 1          1.0       1
# 2          1.0       3
# 3          1.0       1
# 4          0.0       3
# ...        ...     ...
# 1304       NaN       3
# 1305       NaN       1
# 1306       NaN       3
# 1307       NaN       3
# 1308       NaN       3
#
# [1309 rows x 2 columns]

# %% [markdown]
# ### Sex

# %%
# Adicionando o valor 0 para male e 1 para female
titanic_df['Sex'] = titanic_df['Sex'].map({'male':0,'female':1})

# %%
# Adicionando a coluna Sex no dataframe df
df['Sex'] = titanic_df['Sex']
df
# Out:
#       Survived  Pclass  Sex
# 0          0.0       3    0
# 1          1.0       1    1
# 2          1.0       3    1
# 3          1.0       1    1
# 4          0.0       3    0
# ...        ...     ...  ...
# 1304       NaN       3    0
# 1305       NaN       1    1
# 1306       NaN       3    0
# 1307       NaN       3    0
# 1308       NaN       3    0
#
# [1309 rows x 3 columns]

# %% [markdown]
# ### SibSp

# %%
# Utilizando a função para saber algumas informações da coluna SibSp
titanic_func(titanic_df, 'SibSp')
# Out:
# Quantidade de valores únicos: 7
#
# Quais são os valores únicos: [1 0 3 4 2 5 8]
#
# Quantidade de valores nulos: 0
#
# Quantidade por opção:
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: SibSp, dtype: int64

# %%
# Adicionando a coluna SibSp no dataframe df
df['SibSp'] = titanic_df['SibSp']
df
# Out:
#       Survived  Pclass  Sex  SibSp
# 0          0.0       3    0      1
# 1          1.0       1    1      1
# 2          1.0       3    1      0
# 3          1.0       1    1      1
# 4          0.0       3    0      0
# ...        ...     ...  ...    ...
# 1304       NaN       3    0      0
# 1305       NaN       1    1      0
# 1306       NaN       3    0      0
# 1307       NaN       3    0      0
# 1308       NaN       3    0      1
#
# [1309 rows x 4 columns]

# %% [markdown]
# ### Parch

# %%
# Utilizando a função para saber algumas informações da coluna Parch
titanic_func(titanic_df,'Parch')
# Out:
# Quantidade de valores únicos: 8
#
# Quais são os valores únicos: [0 1 2 5 3 4 6 9]
#
# Quantidade de valores nulos: 0
#
# Quantidade por opção:
# 0    1002
# 1     170
# 2     113
# 3       8
# 5       6
# 4       6
# 6       2
# 9       2
# Name: Parch, dtype: int64

# %%
# # Adicionando a coluna Parch no dataframe df
df['Parch'] = titanic_df['Parch']
df
# Out:
#       Survived  Pclass  Sex  SibSp  Parch
# 0          0.0       3    0      1      0
# 1          1.0       1    1      1      0
# 2          1.0       3    1      0      0
# 3          1.0       1    1      1      0
# 4          0.0       3    0      0      0
# ...        ...     ...  ...    ...    ...
# 1304       NaN       3    0      0      0
# 1305       NaN       1    1      0      0
# 1306       NaN       3    0      0      0
# 1307       NaN       3    0      0      0
# 1308       NaN       3    0      1      1
#
# [1309 rows x 5 columns]

# %% [markdown]
# ### FamilySize

# %%
# Criação de uma nova coluna no dataframe titanic_df, representando o tamanho da familia de cada passageiro
titanic_df['FamilySize'] = titanic_df['SibSp'] + titanic_df['Parch'] + 1 
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
#
#              Ticket     Fare Cabin Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN        S           2
# 1          PC 17599  71.2833   C85        C           2
# 2  STON/O2. 3101282   7.9250   NaN        S           1

# %%
# # Adicionando a coluna FamilySize no dataframe df
df['FamilySize'] = titanic_df['FamilySize']
df
# Out:
#       Survived  Pclass  Sex  SibSp  Parch  FamilySize
# 0          0.0       3    0      1      0           2
# 1          1.0       1    1      1      0           2
# 2          1.0       3    1      0      0           1
# 3          1.0       1    1      1      0           2
# 4          0.0       3    0      0      0           1
# ...        ...     ...  ...    ...    ...         ...
# 1304       NaN       3    0      0      0           1
# 1305       NaN       1    1      0      0           1
# 1306       NaN       3    0      0      0           1
# 1307       NaN       3    0      0      0           1
# 1308       NaN       3    0      1      1           3
#
# [1309 rows x 6 columns]

# %% [markdown]
# ### Fare

# %%
# Utilizando a função para saber algumas informações da coluna Fare
titanic_func(titanic_df, 'Fare', False)
# Out:
# Quantidade de valores únicos: 281
#
# Quais são os valores únicos: [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
#   39.6875   7.8     76.7292  61.9792  27.75    46.9     80.      83.475
#   27.9     15.2458   8.1583   8.6625  73.5     14.4542  56.4958   7.65
#   29.      12.475    9.       9.5      7.7875  47.1     15.85    34.375
#   61.175   20.575   34.6542  63.3583  23.      77.2875   8.6542   7.775
#   24.15     9.825   14.4583 247.5208   7.1417  22.3583   6.975    7.05
#   14.5     15.0458  26.2833   9.2167  79.2      6.75    11.5     36.75
#    7.7958  12.525   66.6      7.3125  61.3792   7.7333  69.55    16.1
# ...

# %%
#verificando os dados onde fare é null 
titanic_df[titanic_df['Fare'].isnull()]
# Out:
#       PassengerId  Survived  Pclass                Name  Sex   Age  SibSp  \
# 1043         1044       NaN       3  Storey, Mr. Thomas    0  60.5      0
#
#       Parch Ticket  Fare Cabin Embarked  FamilySize
# 1043      0   3701   NaN   NaN        S           1

# %%
#media do valor da classe 3
titanic_df[titanic_df['Pclass'] == 3]['Fare'].mean()
# Out:
# 13.302888700564969

# %%
# preenche os valores faltantes na coluna 'Fare' com a média dos valores da classe 3
titanic_df['Fare'].fillna(titanic_df[titanic_df['Pclass'] == 3]['Fare'].mean()  , inplace = True)
titanic_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          2
# FamilySize        0
# dtype: int64

# %%
# # Adicionando a coluna Fare no dataframe df
df['Fare'] = titanic_df['Fare']
df
# Out:
#       Survived  Pclass  Sex  SibSp  Parch  FamilySize      Fare
# 0          0.0       3    0      1      0           2    7.2500
# 1          1.0       1    1      1      0           2   71.2833
# 2          1.0       3    1      0      0           1    7.9250
# 3          1.0       1    1      1      0           2   53.1000
# 4          0.0       3    0      0      0           1    8.0500
# ...        ...     ...  ...    ...    ...         ...       ...
# 1304       NaN       3    0      0      0           1    8.0500
# 1305       NaN       1    1      0      0           1  108.9000
# 1306       NaN       3    0      0      0           1    7.2500
# 1307       NaN       3    0      0      0           1    8.0500
# 1308       NaN       3    0      1      1           3   22.3583
#
# [1309 rows x 7 columns]

# %% [markdown]
# ### Embarked

# %%
titanic_func(titanic_df, 'Embarked')
# Out:
# Quantidade de valores únicos: 3
#
# Quais são os valores únicos: ['S' 'C' 'Q' nan]
#
# Quantidade de valores nulos: 2
#
# Quantidade por opção:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
titanic_df[titanic_df['Pclass'] == 1]['Embarked'].value_counts()
# Out:
# S    177
# C    141
# Q      3
# Name: Embarked, dtype: int64

# %%
# acrescenta c na coluna embarked nos valores null
titanic_df['Embarked'].fillna("C", inplace = True)
titanic_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# FamilySize        0
# dtype: int64

# %%
df['Embarked'] = titanic_df['Embarked']
